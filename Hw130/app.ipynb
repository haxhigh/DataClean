# %%
import pandas as pd

df1 = pd.read_csv("Merged_Planets_dwarfs.csv")
df1 = df1.dropna()
del df1["Luminosity"]
df1
# Out:
#     Unnamed: 0.1  Unnamed: 0         Star_name         Distance   Mass  \
# 0              0           0               Sun      0.000015813      1
# 1              1           1            Sirius           0008.6    2.1
# 2              2           3    Alpha Centauri           0004.4    1.1
# 3              3           5              Vega             0025    2.2
# 4              4           7             Rigel             0860     23
# ..           ...         ...               ...              ...    ...
# 72            72          93           WOH G64         0163,000    <20
# 73            73          94        TRAPPIST-1            039.6  0.089
# 74            74          95  2MASS J0523-1403            040.3   0.07
# 75            75          96    WISE 0855−0714            07.27  0.003
# 76            76          97            Icarus  014,400,000,000     33
#
#            Radius                           name  radius  mass  distance
# ...
